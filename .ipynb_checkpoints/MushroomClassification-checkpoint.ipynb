# %% [markdown]
# # Introduction

# %% [markdown]
# #### Author: Vidhi Mehta
# #### Description
# In this project, the primary focus is on feature selection, elploratory data analysis, and using models to solve the binary classification problem.
# #### Overview
# 1. Loading Data and Libraries
# 2. Data Cleaning
# 3. Exploratory Data Analysis
# 4. Binary Logistic Regression Model and Feature Selection

# %% [markdown]
# ____

# %% [markdown]
# ## 1. Loading Data and Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score


from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## 2. Reading In Data

# %%
data = pd.read_csv("mushrooms.csv")
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# First, we will encode the categorical data into numeric data so we can use our models.

# %%
encoder = LabelEncoder()

for col in range(len(data.columns)):
    data[data.columns[col]] = encoder.fit_transform(data[data.columns[col]]) 
    
data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %% [markdown]
# Now we break up the data into X and y.

# %% [markdown]
# I used a scaler to ensure all the data values are in the same scale. This helps with improving the accuracy of the models.

# %%
y = data['class']
X = data.drop('class', axis=1)

scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns= X.columns)

X
# Out:
#       cap-shape  cap-surface  cap-color   bruises      odor  gill-attachment  \
# 0      1.029712     0.140128  -0.198250  1.185917  0.881938         0.162896
# 1      1.029712     0.140128   1.765874  1.185917 -1.970316         0.162896
# 2     -2.087047     0.140128   1.373049  1.185917 -0.544189         0.162896
# 3      1.029712     0.953270   1.373049  1.185917  0.881938         0.162896
# 4      1.029712     0.140128  -0.591075 -0.843230  0.406562         0.162896
# ...         ...          ...        ...       ...       ...              ...
# 8119  -0.216992     0.140128  -0.198250 -0.843230  0.406562        -6.138869
# 8120   1.029712     0.140128  -0.198250 -0.843230  0.406562        -6.138869
# 8121  -0.840343     0.140128  -0.198250 -0.843230  0.406562        -6.138869
# 8122  -0.216992     0.953270  -0.198250 -0.843230  1.832689         0.162896
# 8123   1.029712     0.140128  -0.198250 -0.843230  0.406562        -6.138869
#
# ...

# %% [markdown]
# Now, we split the data into training the testing set. I am using an 80/20 split due to the huge size of the dataset.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %% [markdown]
# For this classification problem, I have decided to train and compare three models
#     1. Logistic Regression
#     2. Support Vector Machine
#     3. K-Nearest Neighbors

# %%
log_model = LogisticRegression()
svm_model = SVC(C=1.0, kernel='rbf')
neigh = KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Training the model with our X and y train sets

# %%
log_model.fit(X_train, y_train)
svm_model.fit(X_train, y_train)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Finally, we test the model with our testing data.

# %%
print(f" Logistic Regression: {log_model.score(X_test, y_test)}")
print(f" Support Vector Machine: {svm_model.score(X_test, y_test)}")
print(f" K-Nearest Neighbors(n=3): {neigh.score(X_test, y_test)}")
# Out:
#  Logistic Regression: 0.9569230769230769
#  Support Vector Machine: 1.0
#  K-Nearest Neighbors(n=3): 1.0

# %% [markdown]
# ## Results

# %% [markdown]
# The logisitic regression model gave us an accuract of 95.69% whereas our SVM and KNN models gave us an accuracy of a whopping 100%.

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
train_scores, test_scores = list(), list()
values = [i for i in range(1, 21)]
for i in values:
    neigh = KNeighborsClassifier(n_neighbors=i)
    neigh.fit(X_train, y_train)
    train_yhat = log_model.predict(X_train)
    train_acc = accuracy_score(y_train, train_yhat)
    train_scores.append(train_acc)
    
    test_yhat = neigh.predict(X_test)
    test_acc = accuracy_score(y_test, test_yhat)
    test_scores.append(test_acc)
    
plt.plot(values, train_scores, '-o', label='Train')
plt.plot(values, test_scores, '-o', label='Test')
plt.legend()
plt.show()

# %% [markdown]
# After running some tests and checking the data heatmap, it doesn't appear that our models are overfitting.
